# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hot_hand = pd.read_csv('NBA Hot Hand Analysis(Sheet1) (1).csv')
hot_hand
# Out:
#    Players and Stats for 2023-24 Season  Points (per 100)  Rebounds (per 100)  \
# 0                 Giannis Antetokounmpo              41.6                15.7
# 1                          Lebron James              34.6                 9.8
# 2                           Bam Adebayo              28.2                15.2
# 3                           Luka Doncic              43.3                11.8
# 4                          Kevin Durant              35.5                 8.7
# 5                     Tyrese Haliburton              29.5                 5.7
# 6               Shai Gilgeous-Alexander              42.4                 7.8
# 7                        Damian Lillard              33.1                 6.0
# 8                          Nikola Jokic              37.8                17.7
# 9                          Jayson Tatum              37.1                11.2
# 10                        Jalen Brunson              40.9                 5.1
# 11                         Devin Booker              36.7                 6.1
# 12                         Tyrese Maxey              34.0                 4.8
# 13                          Joel Embiid              50.9                16.2
# 14                      Anthony Edwards              36.6                 7.7
# 15                        Stephen Curry              39.1                 6.6
# 16                     Donte Divincezno              26.9                 6.3
# 17                         James Harden              23.8                 7.4
# 18                        Kawhi Leonard              34.2                 8.8
# 19                   Karl-Anthony Towns              32.9                12.6
#
#     Assists (per 100)  Blocks (per 100)  Steals (per 100)  \
# 0                 8.9               1.5               1.6
# 1                11.2               0.7               1.7
# 2                 5.7               1.4               1.7
# 3                12.5               0.7               1.8
# 4                 6.6               1.6               1.2
# 5                16.0               1.0               1.8
# 6                 8.8               1.3               2.8
# 7                 9.5               0.3               1.3
# 8                12.8               1.2               2.0
# 9                 6.8               0.8               1.4
# 10                9.6               0.2               1.3
# 11                9.4               0.6               1.2
# 12                8.1               0.6               1.3
# 13                8.2               2.5               1.7
# 14                7.2               0.7               1.8
# 15                7.6               0.6               1.1
# 16                4.6               0.8               2.3
# 17               12.3               1.1               1.5
# 18                5.2               1.3               2.4
# 19                4.6               1.0               1.0
#
#    Field Goal Percentage Three-point Percentage Free Throw Percentage  \
# 0                 61.10%                 27.40%                65.70%
# 1                 54.00%                 41.00%                75.00%
# 2                 52.10%                 35.70%                75.50%
# 3                 48.70%                 38.20%                78.60%
# 4                 52.30%                 41.30%                85.60%
# 5                 47.70%                 36.40%                85.50%
# 6                 53.50%                 35.30%                87.40%
# 7                 42.40%                 35.40%                   92%
# 8                 58.30%                 35.90%                81.70%
# 9                 47.10%                 37.60%                83.30%
# 10                47.90%                 40.10%                84.70%
# 11                49.20%                 36.40%                88.60%
# 12                   45%                 37.30%                86.80%
# 13                52.90%                 38.80%                88.30%
# 14                46.10%                 35.70%                83.60%
# 15                   45%                 40.80%                92.30%
# 16                44.30%                 40.10%                75.40%
# 17                42.80%                 38.10%                87.80%
# 18                52.50%                 41.70%                88.50%
# 19                50.40%                 41.60%                87.30%
#
#     Team Offensive Rating  ...  Hot Hand Rebounds (per 100)  \
# 0                     126  ...                         17.2
# 1                     120  ...                         11.5
# 2                     115  ...                         18.3
# 3                     122  ...                          7.8
# 4                     118  ...                          9.4
# 5                     129  ...                          2.0
# 6                     129  ...                          9.6
# 7                     120  ...                          2.6
# 8                     131  ...                         15.9
# 9                     121  ...                         10.6
# 10                    124  ...                          5.6
# 11                    124  ...                          3.2
# 12                    121  ...                          2.2
# 13                    124  ...                         12.0
# 14                    112  ...                          4.2
# 15                    119  ...                          6.2
# 16                    120  ...                          4.4
# 17                    125  ...                          8.4
# 18                    124  ...                          8.7
# 19                    115  ...                          9.8
#
#    Hot Hand Assists (per 100)  Hot Hand Blocks (per 100)  \
# 0                         6.9                        1.4
# 1                         8.4                        0.7
# 2                         8.6                        2.6
# 3                        11.7                        0.0
# 4                         3.1                        3.1
# 5                        11.2                        1.3
# 6                         8.4                        0.0
# 7                         9.6                        0.6
# 8                        15.9                        1.5
# 9                         6.8                        0.8
# 10                        7.3                        0.0
# 11                       10.6                        0.0
# 12                        8.5                        1.1
# 13                        9.1                        2.8
# 14                        5.9                        0.0
# 15                        4.4                        0.0
# 16                        2.2                        0.0
# 17                       12.8                        0.5
# 18                        7.1                        2.4
# 19                        5.2                        0.6
#
#     Hot Hand Steals (per 100)  Hot Hand Field Goal Percentage  \
# 0                         2.1                          67.50%
# 1                         2.3                          62.90%
# 2                         2.1                          44.10%
# 3                         1.6                             61%
# 4                         1.0                          44.40%
# 5                         2.0                          63.80%
# 6                         2.4                          58.70%
# 7                         1.3                             59%
# 8                         1.0                          63.20%
# 9                         0.8                          46.40%
# 10                        0.8                          48.50%
# 11                        0.0                          47.20%
# 12                        2.2                          51.70%
# 13                        1.4                             60%
# 14                        1.7                          57.10%
# 15                        2.7                          51.30%
# 16                        1.9                          41.70%
# 17                        2.2                          53.10%
# 18                        2.4                          39.30%
# 19                        1.7                          53.80%
#
#     Hot Hand Three-Point Percentage  Hot Hand Free Throw Percentage  \
# 0                                0%                          68.20%
# 1                               40%                          71.40%
# 2                               NaN                          95.20%
# 3                            40.90%                          78.90%
# 4                               40%                             80%
# 5                               60%                            100%
# 6                                0%                             95%
# 7                               52%                             90%
# 8                            37.50%                             50%
# 9                            38.50%                          85.70%
# 10                           55.60%                          71.40%
# 11                           35.70%                          83.30%
# 12                              40%                          88.90%
# 13                              50%                          95.80%
# 14                           53.80%                          83.30%
# 15                              50%                          92.90%
# 16                              40%                             80%
# 17                              35%                          94.40%
# 18                              10%                             50%
# 19                              50%                            100%
#
#    Hot Hand Team Offensive Rating Hot Hand Team Defensive Rating  \
# 0                           111.7                          133.1
# 1                           107.6                          116.4
# 2                           105.9                          102.1
# 3                           138.3                          130.5
# 4                           126.0                          119.8
# 5                           127.6                          110.7
# 6                           116.9                          104.2
# 7                           129.0                          105.8
# 8                           107.7                          108.7
# 9                           112.0                          105.3
# 10                          108.1                          127.6
# 11                          117.0                          119.6
# 12                          100.0                          114.0
# 13                          131.5                          114.8
# 14                          120.2                           95.9
# 15                          119.5                          122.7
# 16                          117.0                          134.2
# 17                          132.4                          132.6
# 18                          107.1                          117.4
# 19                          124.7                          119.0
#
#    Hot Hand Team Record
# 0                  7, 3
# 1                  7, 3
# 2                  7, 3
# 3                  9, 1
# 4                  5, 5
# 5                  6, 4
# 6                  8, 2
# 7                  9, 1
# 8                  4, 6
# 9                  7, 3
# 10                 7, 3
# 11                 7, 3
# 12                 9, 1
# 13                 9, 1
# 14                 9, 1
# 15                 5, 5
# 16                 6, 4
# 17                 7, 3
# 18                 6, 4
# 19                 7, 3
#
# [20 rows x 23 columns]

# %%
hot_hand['Hot Hand Three-Point Percentage'] = hot_hand['Hot Hand Three-Point Percentage'].fillna('0%')
hot_hand['Team Record'] = hot_hand['Team Record'].replace(', ', '-', regex=True)
hot_hand['Hot Hand Team Record'] = hot_hand['Hot Hand Team Record'].replace(', ', '-', regex=True)
hot_hand
# Out:
#    Players and Stats for 2023-24 Season  Points (per 100)  Rebounds (per 100)  \
# 0                 Giannis Antetokounmpo              41.6                15.7
# 1                          Lebron James              34.6                 9.8
# 2                           Bam Adebayo              28.2                15.2
# 3                           Luka Doncic              43.3                11.8
# 4                          Kevin Durant              35.5                 8.7
# 5                     Tyrese Haliburton              29.5                 5.7
# 6               Shai Gilgeous-Alexander              42.4                 7.8
# 7                        Damian Lillard              33.1                 6.0
# 8                          Nikola Jokic              37.8                17.7
# 9                          Jayson Tatum              37.1                11.2
# 10                        Jalen Brunson              40.9                 5.1
# 11                         Devin Booker              36.7                 6.1
# 12                         Tyrese Maxey              34.0                 4.8
# 13                          Joel Embiid              50.9                16.2
# 14                      Anthony Edwards              36.6                 7.7
# 15                        Stephen Curry              39.1                 6.6
# 16                     Donte Divincezno              26.9                 6.3
# 17                         James Harden              23.8                 7.4
# 18                        Kawhi Leonard              34.2                 8.8
# 19                   Karl-Anthony Towns              32.9                12.6
#
#     Assists (per 100)  Blocks (per 100)  Steals (per 100)  \
# 0                 8.9               1.5               1.6
# 1                11.2               0.7               1.7
# 2                 5.7               1.4               1.7
# 3                12.5               0.7               1.8
# 4                 6.6               1.6               1.2
# 5                16.0               1.0               1.8
# 6                 8.8               1.3               2.8
# 7                 9.5               0.3               1.3
# 8                12.8               1.2               2.0
# 9                 6.8               0.8               1.4
# 10                9.6               0.2               1.3
# 11                9.4               0.6               1.2
# 12                8.1               0.6               1.3
# 13                8.2               2.5               1.7
# 14                7.2               0.7               1.8
# 15                7.6               0.6               1.1
# 16                4.6               0.8               2.3
# 17               12.3               1.1               1.5
# 18                5.2               1.3               2.4
# 19                4.6               1.0               1.0
#
#    Field Goal Percentage Three-point Percentage Free Throw Percentage  \
# 0                 61.10%                 27.40%                65.70%
# 1                 54.00%                 41.00%                75.00%
# 2                 52.10%                 35.70%                75.50%
# 3                 48.70%                 38.20%                78.60%
# 4                 52.30%                 41.30%                85.60%
# 5                 47.70%                 36.40%                85.50%
# 6                 53.50%                 35.30%                87.40%
# 7                 42.40%                 35.40%                   92%
# 8                 58.30%                 35.90%                81.70%
# 9                 47.10%                 37.60%                83.30%
# 10                47.90%                 40.10%                84.70%
# 11                49.20%                 36.40%                88.60%
# 12                   45%                 37.30%                86.80%
# 13                52.90%                 38.80%                88.30%
# 14                46.10%                 35.70%                83.60%
# 15                   45%                 40.80%                92.30%
# 16                44.30%                 40.10%                75.40%
# 17                42.80%                 38.10%                87.80%
# 18                52.50%                 41.70%                88.50%
# 19                50.40%                 41.60%                87.30%
#
#     Team Offensive Rating  ...  Hot Hand Rebounds (per 100)  \
# 0                     126  ...                         17.2
# 1                     120  ...                         11.5
# 2                     115  ...                         18.3
# 3                     122  ...                          7.8
# 4                     118  ...                          9.4
# 5                     129  ...                          2.0
# 6                     129  ...                          9.6
# 7                     120  ...                          2.6
# 8                     131  ...                         15.9
# 9                     121  ...                         10.6
# 10                    124  ...                          5.6
# 11                    124  ...                          3.2
# 12                    121  ...                          2.2
# 13                    124  ...                         12.0
# 14                    112  ...                          4.2
# 15                    119  ...                          6.2
# 16                    120  ...                          4.4
# 17                    125  ...                          8.4
# 18                    124  ...                          8.7
# 19                    115  ...                          9.8
#
#    Hot Hand Assists (per 100)  Hot Hand Blocks (per 100)  \
# 0                         6.9                        1.4
# 1                         8.4                        0.7
# 2                         8.6                        2.6
# 3                        11.7                        0.0
# 4                         3.1                        3.1
# 5                        11.2                        1.3
# 6                         8.4                        0.0
# 7                         9.6                        0.6
# 8                        15.9                        1.5
# 9                         6.8                        0.8
# 10                        7.3                        0.0
# 11                       10.6                        0.0
# 12                        8.5                        1.1
# 13                        9.1                        2.8
# 14                        5.9                        0.0
# 15                        4.4                        0.0
# 16                        2.2                        0.0
# 17                       12.8                        0.5
# 18                        7.1                        2.4
# 19                        5.2                        0.6
#
#     Hot Hand Steals (per 100)  Hot Hand Field Goal Percentage  \
# 0                         2.1                          67.50%
# 1                         2.3                          62.90%
# 2                         2.1                          44.10%
# 3                         1.6                             61%
# 4                         1.0                          44.40%
# 5                         2.0                          63.80%
# 6                         2.4                          58.70%
# 7                         1.3                             59%
# 8                         1.0                          63.20%
# 9                         0.8                          46.40%
# 10                        0.8                          48.50%
# 11                        0.0                          47.20%
# 12                        2.2                          51.70%
# 13                        1.4                             60%
# 14                        1.7                          57.10%
# 15                        2.7                          51.30%
# 16                        1.9                          41.70%
# 17                        2.2                          53.10%
# 18                        2.4                          39.30%
# 19                        1.7                          53.80%
#
#     Hot Hand Three-Point Percentage  Hot Hand Free Throw Percentage  \
# 0                                0%                          68.20%
# 1                               40%                          71.40%
# 2                                0%                          95.20%
# 3                            40.90%                          78.90%
# 4                               40%                             80%
# 5                               60%                            100%
# 6                                0%                             95%
# 7                               52%                             90%
# 8                            37.50%                             50%
# 9                            38.50%                          85.70%
# 10                           55.60%                          71.40%
# 11                           35.70%                          83.30%
# 12                              40%                          88.90%
# 13                              50%                          95.80%
# 14                           53.80%                          83.30%
# 15                              50%                          92.90%
# 16                              40%                             80%
# 17                              35%                          94.40%
# 18                              10%                             50%
# 19                              50%                            100%
#
#    Hot Hand Team Offensive Rating Hot Hand Team Defensive Rating  \
# 0                           111.7                          133.1
# 1                           107.6                          116.4
# 2                           105.9                          102.1
# 3                           138.3                          130.5
# 4                           126.0                          119.8
# 5                           127.6                          110.7
# 6                           116.9                          104.2
# 7                           129.0                          105.8
# 8                           107.7                          108.7
# 9                           112.0                          105.3
# 10                          108.1                          127.6
# 11                          117.0                          119.6
# 12                          100.0                          114.0
# 13                          131.5                          114.8
# 14                          120.2                           95.9
# 15                          119.5                          122.7
# 16                          117.0                          134.2
# 17                          132.4                          132.6
# 18                          107.1                          117.4
# 19                          124.7                          119.0
#
#    Hot Hand Team Record
# 0                   7-3
# 1                   7-3
# 2                   7-3
# 3                   9-1
# 4                   5-5
# 5                   6-4
# 6                   8-2
# 7                   9-1
# 8                   4-6
# 9                   7-3
# 10                  7-3
# 11                  7-3
# 12                  9-1
# 13                  9-1
# 14                  9-1
# 15                  5-5
# 16                  6-4
# 17                  7-3
# 18                  6-4
# 19                  7-3
#
# [20 rows x 23 columns]

# %%
raw_player_data = pd.read_csv('Hot Hand Game Data(Sheet1).csv')
raw_player_data
# Out:
#      Unnamed: 0  Points  Rebounds  Blocks  Steals Two Point Shots  \
# 0   Steph Curry      58         7     NaN     3.0           10;19
# 1            KD      38         9     3.0     1.0           10;22
# 2        LeBron      53        15     1.0     3.0           18;25
# 3          Shai      73        16     NaN     4.0           27;42
# 4         Jokic      55        31     3.0     2.0           21;30
# 5           Ant      52         5     NaN     2.0           13;22
# 6           KAT      62        17     1.0     3.0           14;25
# 7       Giannis      68        25     2.0     3.0           27;39
# 8          Book      44         3     NaN     NaN           12;22
# 9           Bam      50        34     5.0     4.0           15;34
# 10         Luka      72        10     NaN     2.0           16;19
# 11   Haliburton      87         3     2.0     3.0           12;17
# 12         Dame      71         4     1.0     2.0           10;14
# 13        Tatum      37        14     1.0     1.0            8;15
# 14      Brunson      47         7     NaN     1.0            6;15
# 15        Maxey      39         2     1.0     2.0           11;19
# 16       Embiid      73        17     4.0     2.0           22;36
# 17   Divincenzo      32         7     NaN     3.0             2;4
# 18       Harden      58        15     1.0     4.0           10;12
# 19        Kawhi      25        11     3.0     3.0           10;17
#
#    Three Point Shots Free Throws  Points Scored (Team)  Points Allowed (Team)  \
# 0               9;18       13;14                   135                    135
# 1                2;5       12;15                   121                    115
# 2               4;10         5;7                   141                    156
# 3                0;4       19;20                   194                    173
# 4                3;8         4;8                   210                    212
# 5               7;13         5;6                   143                    116
# 6               7;14       13;13                   217                    207
# 7                0;1       15;22                   162                    193
# 8               5;14         5;6                   110                    116
# 9                NaN       20;21                   197                    193
# 10              9;22       15;19                   177                    167
# 11             18;30         9;9                   194                    165
# 12             13;25       18;20                   200                    164
# 13              5;13         6;7                   149                    139
# 14             10;18         5;7                   134                    162
# 15              4;10         8;9                    94                    106
# 16               2;4       23;24                   188                    163
# 17              8;20         4;5                   186                    216
# 18              7;20       17;18                   237                    244
# 19              1;10         2;4                   135                    148
#
#     Total Possessions (Offense)  Total Possessions (Defense)  Team +/-  \
# 0                           113                          110       0.0
# 1                            96                           96       6.0
# 2                           131                          134       NaN
# 3                           166                          166       NaN
# 4                           195                          195       NaN
# 5                           119                          121       NaN
# 6                           174                          174       NaN
# 7                           145                          145       NaN
# 8                            94                           97       NaN
# 9                           186                          189       NaN
# 10                          128                          128       NaN
# 11                          152                          149       NaN
# 12                          157                          155       NaN
# 13                          133                          132       NaN
# 14                          124                          127       NaN
# 15                           94                           93       NaN
# 16                          143                          142       NaN
# 17                          159                          161       NaN
# 18                          179                          184       NaN
# 19                          126                          126       NaN
#
#     Assists  Turnovers                                              Notes
# 0         5          4  Shot quality decreases, they don't feed him, t...
# 1         3          3  Shot quality again decreases, multiple times t...
# 2        11         10  Ferociocsly attacked the paint when hot, force...
# 3        14          6          A lot of off dribble contested jump shots
# 4        31          8                                                NaN
# 5         7          4                                                NaN
# 6         9          3  When he gets hot, he gets em up quick; didn't ...
# 7        10         12                                                NaN
# 8        10          1          A lot of off dribble contested jump shots
# 9        16          5  More "turnarounds" and jump shots; got much be...
# 10       15          3  vs Clippers was CRAZY (was at 51 pts in 61 pos...
# 11       17          6  Started 9;11 from 3; trailing 110-109 vs Atlan...
# 12       15          4  Ton of off-dribble 3s (30 ft); did this in 4Q ...
# 13        9          3                         Shot selection takes a hit
# 14        9          5                                                NaN
# 15        8          4  So many pull up jump shots; all efficiency and...
# 16       13          2                                                NaN
# 17        2          5                                                NaN
# 18       23          5  Came out of game after hitting 3rd shot in a r...
# 19        9          1                                                NaN

# %%
raw_player_data['Blocks'] = raw_player_data['Blocks'].fillna(0)
raw_player_data['Steals'] = raw_player_data['Steals'].fillna(0)
raw_player_data = raw_player_data.drop('Team +/-', axis=1)
raw_player_data['Three Point Shots'] = raw_player_data['Three Point Shots'].fillna('0;0')

# %%
raw_player_data = raw_player_data.rename(columns = {'Unnamed: 0': 'Player Name'})

# %%
raw_player_data['Two Point Shots'] = raw_player_data['Two Point Shots'].replace(';', '/', regex=True)
raw_player_data['Three Point Shots'] = raw_player_data['Three Point Shots'].replace(';', '/', regex=True)
raw_player_data['Free Throws'] = raw_player_data['Free Throws'].replace(';', '/', regex=True)

# %%
raw_player_data = raw_player_data.drop('Notes', axis=1)

# %%
raw_player_data
# Out:
#     Player Name  Points  Rebounds  Blocks  Steals Two Point Shots  \
# 0   Steph Curry      58         7     0.0     3.0           10/19
# 1            KD      38         9     3.0     1.0           10/22
# 2        LeBron      53        15     1.0     3.0           18/25
# 3          Shai      73        16     0.0     4.0           27/42
# 4         Jokic      55        31     3.0     2.0           21/30
# 5           Ant      52         5     0.0     2.0           13/22
# 6           KAT      62        17     1.0     3.0           14/25
# 7       Giannis      68        25     2.0     3.0           27/39
# 8          Book      44         3     0.0     0.0           12/22
# 9           Bam      50        34     5.0     4.0           15/34
# 10         Luka      72        10     0.0     2.0           16/19
# 11   Haliburton      87         3     2.0     3.0           12/17
# 12         Dame      71         4     1.0     2.0           10/14
# 13        Tatum      37        14     1.0     1.0            8/15
# 14      Brunson      47         7     0.0     1.0            6/15
# 15        Maxey      39         2     1.0     2.0           11/19
# 16       Embiid      73        17     4.0     2.0           22/36
# 17   Divincenzo      32         7     0.0     3.0             2/4
# 18       Harden      58        15     1.0     4.0           10/12
# 19        Kawhi      25        11     3.0     3.0           10/17
#
#    Three Point Shots Free Throws  Points Scored (Team)  Points Allowed (Team)  \
# 0               9/18       13/14                   135                    135
# 1                2/5       12/15                   121                    115
# 2               4/10         5/7                   141                    156
# 3                0/4       19/20                   194                    173
# 4                3/8         4/8                   210                    212
# 5               7/13         5/6                   143                    116
# 6               7/14       13/13                   217                    207
# 7                0/1       15/22                   162                    193
# 8               5/14         5/6                   110                    116
# 9                0/0       20/21                   197                    193
# 10              9/22       15/19                   177                    167
# 11             18/30         9/9                   194                    165
# 12             13/25       18/20                   200                    164
# 13              5/13         6/7                   149                    139
# 14             10/18         5/7                   134                    162
# 15              4/10         8/9                    94                    106
# 16               2/4       23/24                   188                    163
# 17              8/20         4/5                   186                    216
# 18              7/20       17/18                   237                    244
# 19              1/10         2/4                   135                    148
#
#     Total Possessions (Offense)  Total Possessions (Defense)  Assists  \
# 0                           113                          110        5
# 1                            96                           96        3
# 2                           131                          134       11
# 3                           166                          166       14
# 4                           195                          195       31
# 5                           119                          121        7
# 6                           174                          174        9
# 7                           145                          145       10
# 8                            94                           97       10
# 9                           186                          189       16
# 10                          128                          128       15
# 11                          152                          149       17
# 12                          157                          155       15
# 13                          133                          132        9
# 14                          124                          127        9
# 15                           94                           93        8
# 16                          143                          142       13
# 17                          159                          161        2
# 18                          179                          184       23
# 19                          126                          126        9
#
#     Turnovers
# 0           4
# 1           3
# 2          10
# 3           6
# 4           8
# 5           4
# 6           3
# 7          12
# 8           1
# 9           5
# 10          3
# 11          6
# 12          4
# 13          3
# 14          5
# 15          4
# 16          2
# 17          5
# 18          5
# 19          1

# %% [markdown]
# I had to clean the 'raw_player_data' dataset because I had put some missing values in that I wanted replaced with 0s; I also decided to get rid of the 'Team +/-' column because it was unimportant. I named the unnamed column 'player name', which I had forgotten to do previously and changed the semicolons to slashes to make the shooting splits look better. Finally, I removed the notes column so the dataset would remain solely numerical outside of player names.

# %%
pp100_sum = hot_hand['Points (per 100)'].sum()
pp100_sum
# Out:
# np.float64(719.1)

# %%
hhpp100_sum = hot_hand['Hot Hand Points (per 100)'].sum()
hhpp100_sum
# Out:
# np.float64(794.4999999999999)

# %%
(hhpp100_sum) - (pp100_sum)
# Out:
# np.float64(75.39999999999986)

# %%
((hhpp100_sum) - (pp100_sum)) / 20
# Out:
# np.float64(3.7699999999999934)

# %% [markdown]
# The 20 players combined scored 75.4 more points per 100 possessions when they had the hot hand; that averages out to a 3.77 points per 100 possessions increase per player.

# %%
ap100 = hot_hand['Assists (per 100)'].sum()
rp100 = hot_hand['Rebounds (per 100)'].sum()
bp100 = hot_hand['Blocks (per 100)'].sum()
sp100 = hot_hand['Steals (per 100)'].sum()

# %%
print (ap100)
print (rp100)
print (bp100)
print (sp100)
# Out:
# 175.6
# 191.20000000000002
# 19.900000000000002
# 32.9

# %%
hhap100 = hot_hand['Hot Hand Assists (per 100)'].sum()
hhrp100 = hot_hand['Hot Hand Rebounds (per 100)'].sum()
hhbp100 = hot_hand['Hot Hand Blocks (per 100)'].sum()
hhsp100 = hot_hand['Hot Hand Steals (per 100)'].sum()

# %%
print (hhap100)
print (hhrp100)
print (hhbp100)
print (hhsp100)
# Out:
# 163.69999999999996
# 169.60000000000002
# 19.4
# 33.599999999999994

# %% [markdown]
# For the other 4 main stats - rebounds, assists, blocks, and steals - steals is the only one that increases with the hot hand.

# %%
x_labels = hot_hand['Players and Stats for 2023-24 Season']
x_pos = np.arange(len(hot_hand))

hot_hand.index = [f'Row {i+1}' for i in range(20)]

x = np.arange(len(hot_hand)) 
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width/2, hot_hand['Field Goal Percentage'], width, label='FG% Without Hot Hand')
bars2 = ax.bar(x + width/2, hot_hand['Hot Hand Field Goal Percentage'], width, label='FG% With Hot Hand')

for bar in bars1:

    height = bar.get_height()

    ax.annotate(f'{height:.1f}%',

                xy=(bar.get_x() + bar.get_width() / 2, height),

                xytext=(0, 3),  # 3 points vertical offset

                textcoords="offset points",

                ha='center', va='bottom')

 

for bar in bars2:

    height = bar.get_height()

    ax.annotate(f'{height:.1f}%',

                xy=(bar.get_x() + bar.get_width() / 2, height),

                xytext=(0, 3),

                textcoords="offset points",

                ha='center', va='bottom')


ax.set_xlabel('Rows')
ax.set_ylabel('Values')
ax.set_title('Comparison of FG% with and without the hot hand')
ax.set_xticks(x_pos)
ax.set_xticklabels(x_labels, rotation=75)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

x = np.arange(len(hot_hand)) 
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width/2, hot_hand['Field Goal Percentage'], width, label='FG% Without Hot Hand')
bars2 = ax.bar(x + width/2, hot_hand['Hot Hand Field Goal Percentage'], width, label='FG% With Hot Hand')

# Y-axis from 0 to 70%
ax.set_ylim(0, 70)
ax.set_yticks(np.arange(0, 75, 5))
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# Labels and title
ax.set_xlabel('Rows')
ax.set_ylabel('Field Goal Percentage')
ax.set_title('Comparison of FG% with and without the hot hand')
ax.set_xticks(x)
ax.set_xticklabels(hot_hand.index, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()
